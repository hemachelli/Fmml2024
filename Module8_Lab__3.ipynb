# %% [markdown]
# <a href="https://colab.research.google.com/github/hemachelli/Fmml2024/blob/main/Module8_Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-16 05:13:50--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  76.6MB/s    in 0.9s
#
# 2025-03-16 05:13:51 (76.6 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6932   1707.07576v1  In this work we present the novel ASTRID metho...  stat
# 38925   1402.0936v2  Slice interpolation is a fast growing field in...    cs
# 9651    1412.4044v2  In this paper, we present GASG21 (Grassmannian...  stat
# 34964   1405.2168v1  In this paper a new evolutionary algorithm, fo...    cs
# 3268    1312.6965v1  Using supervised machine learning approaches t...  stat
# ...             ...                                                ...   ...
# 14280  1605.07689v3  We present a Communication-efficient Surrogate...  stat
# 11952  1705.02627v1  It is of fundamental importance to find algori...  stat
# 29636  1709.10437v1  Estimating shape and appearance of a three dim...    cs
# 20094   1409.0069v1  There is a relatively small amount of research...    cs
# 1785   1607.04492v2  Recurrent neural networks (RNNs) process input...    cs
#
#                                                    title  year  \
# 6932   Interpreting Classifiers through Attribute Int...  2017
# 38925  An Optimization Method For Slice Interpolation...  2014
# 9651   Adaptive Stochastic Gradient Descent on the Gr...  2014
# 34964  Evaluation The Efficiency Of Cuckoo Optimizati...  2014
# 3268   An Unsupervised Approach for Automatic Activit...  2013
# ...                                                  ...   ...
# 14280  Communication-Efficient Distributed Statistica...  2016
# 11952  Learning of Gaussian Processes in Distributed ...  2017
# 29636  Optimisation of photometric stereo methods by ...  2017
# 20094  Personalization of Itineraries search using On...  2014
# 1785         Neural Tree Indexers for Text Understanding  2016
#
#                                                 keywords
# 6932   [investigating, attribute, interactions, class...
# 38925  [interpolation, processing, intensity, interpo...
# 9651   [stochastic, stochastic, algorithm, reformulat...
# 34964  [evolutionary, algorithm, continuous, nonlinea...
# 3268   [supervised, approaches, recognize, activities...
# ...                                                  ...
# 14280  [communication, efficient, surrogate, likeliho...
# 11952  [fundamental, importance, algorithms, obtainin...
# 29636  [estimating, appearance, dimensional, techniqu...
# 20094  [relatively, movements, passenger, commercial,...
# 1785   [recurrent, sequentially, conditional, transit...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6932     [investigating, attribute, interactions, class...
# 38925    [interpolation, processing, intensity, interpo...
# 9651     [stochastic, stochastic, algorithm, reformulat...
# 34964    [evolutionary, algorithm, continuous, nonlinea...
# 3268     [supervised, approaches, recognize, activities...
#                                ...
# 11179    [establishes, consistency, algorithms, cluster...
# 4343     [diffusion, resonance, reconstruct, tractograp...
# 35525    [superposition, established, procedure, repres...
# 14950    [statistical, languages, frequency, distributi...
# 21443    [introduces, epistemic, generalization, episte...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8843 words.
# Out of those 4561 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ca8cb748-2ef1-46f4-8633-42ab32c2a87e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca8cb748-2ef1-46f4-8633-42ab32c2a87e")) {                    Plotly.newPlot(                        "ca8cb748-2ef1-46f4-8633-42ab32c2a87e",                        [{"x":["associations","investigate","interpretable","particular","investigating","classification","factorisation","interactions","generating","predictions","attribute","knowledge","partitioning","interpreting","nucleotide","classifiers","distribution","polymorphisms","revealing","bioinformatics","empirically","demonstrate","applications","attributes","intensity","processing","interpolate","registration","difference","displacement","improvement","evaluated","preserving","curvature","quantitatively","intensities","optimization","literature","interpolation","furthermore","corrupted","extension","accelerate","algorithm","numerical","clustering","stochastic","gradients","grassmann","constraint","algorithms","reformulate","constrained","initialization","grassmannian","consecutive","synthetic","leveraging","adaptively","efficiency","experiments","minimization","corruption","subspaces","convergence","continuous","dimensions","evaluation","comparing","performance","nonlinear","evaluating","mentioned","difficult","capability","evolutionary","application","obtaining","segmentation","unsupervised","framework","generally","regression","appearance","multidimensional","available","experimental","acceleration","information","automatic","expectation","consuming","activities","accurately","accelerometers","sequential","maximization","therefore","expensive","recognition","recognize","approaches","supervised","relations","properties","descriptions","variability","representations","distinguishes","determinants","fulfilling","underlies","cognitive","parsimony","linguistic","developmental","theoretical","ontologies","dependences","childrens","introduce","underlying","psycholinguistic","functional","cognition","computational","categories","capacities","descriptive","development","modelling","unsuitable","consequently","selection","methodological","interpretation","preferred","important","comparison","widespread","equivalent","submodular","prototypes","scientific","generalizes","actionability","approximation","addressing","questionnaires","qualitatively","associate","additional","effective","prototypical","efficient","indicative","presumably","symmetric","questions","maintained","maintains","providing","importance","guarantees","submodularity","prototype","published","selecting","requirement","objective","including","illustrate","hyperparameters","generalize","prediction","estimation","techniques","connection","iterations","hyperparameter","parameters","practical","highlighting","dependent","represented","facilitates","completion","promising","sufficient","predicted","hierarchical","convolutional","resolution","reconstruction","limitation","financial","derivatives","implement","randomized","probability"],"y":[14,146,23,253,14,505,1,67,106,95,41,379,19,15,0,103,235,0,8,7,60,574,427,60,27,304,7,33,74,12,140,164,61,11,29,11,304,126,19,166,18,64,21,846,76,137,124,31,2,100,619,6,62,39,0,14,131,39,20,164,586,73,6,22,94,123,39,226,70,880,49,56,19,139,50,66,266,43,193,145,606,68,115,75,20,308,393,14,696,183,36,36,39,53,2,76,38,155,68,352,47,416,197,97,206,40,31,237,5,2,2,1,45,1,60,2,137,30,1,3,313,117,4,41,14,307,64,5,18,134,60,6,35,181,3,61,13,363,125,13,55,14,8,32,35,1,128,23,1,27,10,121,226,1,399,3,2,14,64,8,10,90,86,64,4,19,39,42,31,157,261,78,17,54,210,232,354,40,27,13,260,170,11,75,91,14,34,94,56,46,91,382,139,110,33,4,9,74,24,171],"type":"bar"},{"x":["associations","investigate","interpretable","part ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4561,), (4561, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8125

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Towards</span> <span style=''>a</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3536585365853659);'>Reinforcement</span> <span style=''>Learning</span> <span style=''>Approach</span> <span style=''>for</span> <span style=''>Tower</span> <span style=''>Line</span> <span style=''>Wars</span> <br/><br/><span style=''>There</span> <span style=''>have</span> <span style=''>been</span> <span style=''>numerous</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>breakthroughs</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3536585365853659);'>reinforcement</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>the</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>perhaps</span> <span style=''>most</span> <span style=''>notably</span> <span style=''>on</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3536585365853659);'>Reinforcement</span> <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successfully</span> <span style=''>playing</span> <span style=''>and</span> <span style=''>winning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>advanced</span> <span style=''>computer</span> <span style=''>games</span> <span style=''>There</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>undoubtedly</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>anticipation</span> <span style=''>that</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3536585365853659);'>Reinforcement</span> <span style=''>Learning</span> <span style=''>will</span> <span style=''>play</span> <span style=''>a</span> <span style=''>major</span> <span style=''>role</span> <span style=''>when</span> <span style=''>the</span> <span style=''>first</span> <span style=''>AI</span> <span style=''>masters</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complicated</span> <span style=''>game</span> <span style=''>plays</span> <span style=''>needed</span> <span style=''>to</span> <span style=''>beat</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>professional</span> <span style=''>Real</span> <span style=''>Time</span> <span style=''>Strategy</span> <span style=''>game</span> <span style=''>player</span> <span style=''>For</span> <span style=''>this</span> <span style=''>to</span> <span style=''>be</span> <span style=''>possible</span> <span style=''>there</span> <span style=''>needs</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style=''>game</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857143);'>environment</span> <span style=''>that</span> <span style=''>targets</span> <span style=''>and</span> <span style=''>fosters</span> <span style=''>AI</span> <span style=''>research</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specifically</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3536585365853659);'>Reinforcement</span> <span style=''>Learning</span> <span style=''>Some</span> <span style=''>game</span> <span style='background-color:rgba(0, 255, 0, 0.4807692307692307);'>environments</span> <span style=''>already</span> <span style=''>exist</span> <span style=''>however</span> <span style=''>these</span> <span style=''>are</span> <span style=''>either</span> <span style=''>overly</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>simplistic</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Atari</span> <span style=''>2600</span> <span style=''>or</span> <span style=''>complex</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Starcraft</span> <span style=''>II</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>Mixture</span> <span style=''>Models</span> <br/><br/><span style=''>We</span> <span style=''>take</span> <span style=''>a</span> <span style=''>new</span> <span style=''>look</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>Mixture</span> <span style=''>Models</span> <span style=''>(GMMs)</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>using</span> <span style=''>emphRiemannian</span> <span style=''>manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>as</span> <span style=''>a</span> <span style=''>powerful</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>counterpart</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Maximization</span> <span style=''>(EM)</span> <span style=''>An</span> <span style=''>out</span> <span style=''>of</span> <span style=''>the</span> <span style=''>box</span> <span style=''>invocation</span> <span style=''>of</span> <span style=''>manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>however</span> <span style=''>fails</span> <span style=''>spectacularly</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>to</span> <span style=''>the</span> <span style=''>same</span> <span style=''>solution</span> <span style=''>but</span> <span style=''>vastly</span> <span style=''>slower</span> <span style=''>Driven</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intuition</span> <span style=''>from</span> <span style=''>manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convexity</span> <span style=''>we</span> <span style=''>then</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>reparamerization</span> <span style=''>that</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>remarkable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consequences</span> <span style=''>It</span> <span style=''>makes</span> <span style=''>manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>not</span> <span style=''>only</span> <span style=''>match</span> <span style=''>EM</span> <span style=''>a</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encouraging</span> <span style=''>result</span> <span style=''>in</span> <span style=''>itself</span> <span style=''>given</span> <span style=''>the</span> <span style=''>poor</span> <span style=''>record</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>had</span> <span style=''>against</span> <span style=''>EM</span> <span style=''>so</span> <span style=''>far</span> <span style=''>but</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperform</span> <span style=''>EM</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>settings</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>displaying</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Spectral</span> <span style=''>Learning</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Supervised</span> <span style=''>Topic</span> <span style=''>Models</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Supervised</span> <span style=''>topic</span> <span style=''>models</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>model</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>topic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>large</span> <span style='background-color:rgba(0, 255, 0, 0.5428571428571428);'>collections</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6781609195402298);'>documents</span> <span style=''>and</span> <span style=''>a</span> <span style=''>response</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>each</span> <span style=''>document</span> <span style=''>Existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.616326530612245);'>variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>or</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>sampling</span> <span style=''>which</span> <span style=''>often</span> <span style=''>suffers</span> <span style=''>from</span> <span style=''>the</span> <span style=''>local</span> <span style=''>minimum</span> <span style=''>defect</span> <span style=''>Spectral</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>been</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>learn</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>topic</span> <span style=''>models</span> <span style=''>such</span> <span style=''>as</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>allocation</span> <span style=''>(LDA)</span> <span style=''>with</span> <span style=''>provable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.5263157894736841);'>investigates</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.5918367346938775);'>possibility</span> <span style=''>of</span> <span style=''>applying</span> <span style=''>spectral</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>recover</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>LDA</span> <span style=''>(sLDA)</span> <span style=''>We</span> <span style=''>first</span> <span style=''>present</span> <span style=''>a</span> <span style=''>two</span> <span style=''>stage</span> <span style=''>spectral</span> <span style=''>method</span> <span style=''>which</span> <span style=''>recovers</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>LDA</span> <span style=''>followed</span> <span style=''>by</span> <span style=''>a</span> <span style=''>power</span> <span style=''>update</span> <span style=''>method</span> <span style=''>to</span> <span style=''>recover</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5418326693227091);'>regression</span> <span style=''>model ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>DAGGER</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>FDR</span> <span style=''>control</span> <span style=''>on</span> <span style=''>DAGs</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>top</span> <span style=''>down</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>multiple</span> <span style=''>testing</span> <span style=''>on</span> <span style=''>directed</span> <span style=''>acyclic</span> <span style=''>graphs</span> <span style=''>(DAGs)</span> <span style=''>where</span> <span style=''>nodes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypotheses</span> <span style=''>and</span> <span style=''>edges</span> <span style=''>specify</span> <span style=''>a</span> <span style=''>partial</span> <span style=''>ordering</span> <span style=''>in</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypotheses</span> <span style=''>must</span> <span style=''>be</span> <span style=''>tested</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guaranteed</span> <span style=''>to</span> <span style=''>reject</span> <span style=''>a</span> <span style=''>sub</span> <span style=''>DAG</span> <span style=''>with</span> <span style=''>bounded</span> <span style=''>false</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discovery</span> <span style=''>rate</span> <span style=''>(FDR)</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>satisfying</span> <span style=''>the</span> <span style=''>logical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraint</span> <span style=''>that</span> <span style=''>a</span> <span style=''>rejected</span> <span style=''>nodes</span> <span style=''>parents</span> <span style=''>must</span> <span style=''>also</span> <span style=''>be</span> <span style=''>rejected</span> <span style=''>It</span> <span style=''>is</span> <span style=''>designed</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>testing</span> <span style=''>settings</span> <span style=''>when</span> <span style=''>the</span> <span style=''>DAG</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>is</span> <span style=''>known</span> <span style=''>a</span> <span style=''>priori</span> <span style=''>but</span> <span style=''>the</span> <span style=''>p</span> <span style=''>values</span> <span style=''>are</span> <span style=''>obtained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selectively</span> <span style=''>(such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>conduction</span> <span style=''>of</span> <span style=''>experiments)</span> <span style=''>but</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>in</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>settings</span> <span style=''>when</span> <span style=''>all</span> <span style=''>p</span> <span style=''>values</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>calculated</span> <span style=''>in</span> <span style=''>advance</span> <span style=''>(such</sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08288865172536464)
# 	segmentation (0.06865884027036642)
# 	experimental (0.13980789754535752)
# 	knowledge (0.13482746353610814)
# 	processing (0.10814656705798648)
# 	detection (0.12202063322660975)
# 	information (0.24759871931696906)
# 	recognition (0.12522234080398434)
# 	different (0.2671647100675916)
# 	convolutional (0.13589469939523302)
#
# Some Statistics words are:
# 	estimation (0.16842634489693314)
# 	distribution (0.17647058823529413)
# 	variables (0.13574660633484162)
# 	statistical (0.1568627450980392)
# 	stochastic (0.14027149321266968)
# 	algorithm (0.4007038712921066)
# 	theoretical (0.1493212669683258)
# 	inference (0.20211161387631976)
# 	dimensional (0.19658119658119658)
# 	regression (0.19457013574660634)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="13c7c26b-8318-4c6b-94bd-b7cd9e1b099d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13c7c26b-8318-4c6b-94bd-b7cd9e1b099d")) {                    Plotly.newPlot(                        "13c7c26b-8318-4c6b-94bd-b7cd9e1b099d",                        [{"x":["associations","investigate","interpretable","particular","investigating","classification","factorisation","interactions","generating","predictions","attribute","knowledge","partitioning","interpreting","nucleotide","classifiers","distribution","polymorphisms","revealing","bioinformatics","empirically","demonstrate","applications","attributes","intensity","processing","interpolate","registration","difference","displacement","improvement","evaluated","preserving","curvature","quantitatively","intensities","optimization","literature","interpolation","furthermore","corrupted","extension","accelerate","algorithm","numerical","clustering","stochastic","gradients","grassmann","constraint","algorithms","reformulate","constrained","initialization","grassmannian","consecutive","synthetic","leveraging","adaptively","efficiency","experiments","minimization","corruption","subspaces","convergence","continuous","dimensions","evaluation","comparing","performance","nonlinear","evaluating","mentioned","difficult","capability","evolutionary","application","obtaining","segmentation","unsupervised","framework","generally","regression","appearance","multidimensional","available","experimental","acceleration","information","automatic","expectation","consuming","activities","accurately","accelerometers","sequential","maximization","therefore","expensive","recognition","recognize","approaches","supervised","relations","properties","descriptions","variability","representations","distinguishes","determinants","fulfilling","underlies","cognitive","parsimony","linguistic","developmental","theoretical","ontologies","dependences","childrens","introduce","underlying","psycholinguistic","functional","cognition","computational","categories","capacities","descriptive","development","modelling","unsuitable","consequently","selection","methodological","interpretation","preferred","important","comparison","widespread","equivalent","submodular","prototypes","scientific","generalizes","actionability","approximation","addressing","questionnaires","qualitatively","associate","additional","effective","prototypical","efficient","indicative","presumably","symmetric","questions","maintained","maintains","providing","importance","guarantees","submodularity","prototype","published","selecting","requirement","objective","including","illustrate","hyperparameters","generalize","prediction","estimation","techniques","connection","iterations","hyperparameter","parameters","practical","highlighting","dependent","represented","facilitates","completion","promising","sufficient","predicted","hierarchical","convolutional","resolution","reconstruction","limitation","financial","derivatives","implement","randomized","probability","motivated","probabilistic","frequentist","generalizing","strategies","posterior","inference","approximate","combination","reminiscent","corresponding","responses","bisection","generalized","differently","estimators","illustrated","successfully","generalization","interpretations","reproducibility","parameter","approximating","formulated","regularization","intuitive","empirical","formulation","exploiting","looseness","informatics","suboptimal","biomedical","regularizer","effectiveness","aggregate","increasing","challenging","challenge","contemporary","competitive","combining","searchlight","autoencoder","aggregation","respectively","parallelizable","constraints","parallelism","attractive","partition", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nucleotide
# 	polymorphisms
# 	grassmannian
# 	looseness
# 	searchlight
# 	nonparametrics
# 	internally
# 	unscented
# 	kronecker
# 	minimised
# 	partitional
# 	nonlinearly
# 	stagewise
# 	underestimates
# 	marginalisation
# 	couplings
# 	affirmative
# 	censoring
# 	unprocessed
# 	gaussianity
# Some words which never appear in Statistics papers:
# 	displacement
# 	psycholinguistic
# 	capacities
# 	concurrently
# 	existential
# 	discounts
# 	propositional
# 	satisfiability
# 	destructive
# 	accelerators
# 	fabricated
# 	accelerator
# 	withdrawn
# 	metaheuristic
# 	metaheuristics
# 	orthography
# 	resourced
# 	experimented
# 	tunneling
# 	autonomously

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0608184628569685e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7625
